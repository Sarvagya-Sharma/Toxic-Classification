# %%
import streamlit as st
import pickle
import numpy as np
import re
import string

@st.cache_resource
def load_artifacts():
    with open('rf_model.pkl', 'rb') as f:
        model = pickle.load(f)
    with open('vectorizer.pkl', 'rb') as f:
        vectorizer = pickle.load(f)
    embedding_matrix = np.load('embedding_matrix.npy')
    
    return model, vectorizer, embedding_matrix

model, vectorizer, embedding_matrix = load_artifacts()

def preprocess_text(sen):
  sen = sen.lower()
  sen = sen.translate(str.maketrans('', '', string.punctuation))
  sen = re.sub('[^a-zA-Z]', ' ', sen)
  sen = re.sub(r'\s+[a-zA-Z]\s+', ' ', sen)
  sen = re.sub(r'\s+', ' ', sen)
  return sen


st.title('Toxic Comment Classifier')
st.write('Enter a comment below to see if it\'s classified as toxic or not.')
user_input = st.text_area('Comment:', 'Enter your text here...')

if st.button('Classify'):
    if user_input:
        processed_input = preprocess_text(user_input)
        tfidf_vec = vectorizer.transform([processed_input])
        doc_embed = tfidf_vec.dot(embedding_matrix)
        prediction = model.predict(doc_embed)[0] # Will be True or False
        probability = model.predict_proba(doc_embed)[0][1] # Prob of "Toxic"
        if prediction == True:
            st.error(f'**Classification: TOXIC** (Probability: {probability:.2%})')
        else:
            st.success(f'**Classification: NOT TOXIC** (Probability: {1-probability:.2%})')
            
    else:
        st.warning('Please enter a comment to classify.')

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<26,>=20 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (6.33.1)
# Collecting pyarrow<22,>=7.0 (from streamlit)
#   Downloading pyarrow-21.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (9.1.2)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit)
#   Downloading narwhals-2.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\nlp_env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.51.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.2 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.2 MB 6.5 MB/s eta 0:00:02
# Resuming download streamlit-1.51.0-py3-none-any.whl (2.1 MB/10.2 MB)
#    -------- ------------------------------- 2.1/10.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.9/10.2 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.2 MB 6.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.3/10.2 MB 6.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.2 MB 6.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.2 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 6.5 MB/s  0:00:01
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 5.0 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading pyarrow-21.0.0-cp310-cp310-win_amd64.whl (26.2 MB)
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    - -------------------------------------- 1.0/26.2 MB 5.6 MB/s eta 0:00:05
#    -- ------------------------------------- 1.8/26.2 MB 4.6 MB/s eta 0:00:06
#    --- ------------------------------------ 2.1/26.2 MB 4.1 MB/s eta 0:00:06
#    --- ------------------------------------ 2.6/26.2 MB 3.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.9/26.2 MB 2.8 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.1/26.2 MB 2.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 3.4/26.2 MB 2.5 MB/s eta 0:00:10
#    ----- ---------------------------------- 3.7/26.2 MB 2.4 MB/s eta 0:00:10
#    ----- ---------------------------------- 3.9/26.2 MB 2.3 MB/s eta 0:00:10
#    ------ --------------------------------- 4.5/26.2 MB 2.1 MB/s eta 0:00:11
#    ------- -------------------------------- 4.7/26.2 MB 2.1 MB/s eta 0:00:11
#    ------- -------------------------------- 5.2/26.2 MB 2.1 MB/s eta 0:00:11
#    -------- ------------------------------- 5.8/26.2 MB 2.1 MB/s eta 0:00:10
#    --------- ------------------------------ 6.6/26.2 MB 2.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 7.1/26.2 MB 2.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 7.6/26.2 MB 2.2 MB/s eta 0:00:09
#    ------------ --------------------------- 8.1/26.2 MB 2.3 MB/s eta 0:00:08
#    ------------- -------------------------- 8.7/26.2 MB 2.3 MB/s eta 0:00:08
#    ------------- -------------------------- 9.2/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/26.2 MB 2.3 MB/s eta 0:00:08
# Resuming download pyarrow-21.0.0-cp310-cp310-win_amd64.whl (9.4 MB/26.2 MB)
#    -------------- ------------------------- 9.4/26.2 MB ? eta -:--:--
#    --------------- ------------------------ 10.5/26.2 MB 5.6 MB/s eta 0:00:03
#    ------------------ --------------------- 12.1/26.2 MB 7.0 MB/s eta 0:00:03
#    ------------------- -------------------- 12.8/26.2 MB 5.5 MB/s eta 0:00:03
#    --------------------- ------------------ 14.2/26.2 MB 5.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 15.2/26.2 MB 5.8 MB/s eta 0:00:02
#    ------------------------- -------------- 16.8/26.2 MB 6.0 MB/s eta 0:00:02
#    --------------------------- ------------ 18.4/26.2 MB 6.3 MB/s eta 0:00:02
#    ------------------------------- -------- 20.4/26.2 MB 6.6 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.2 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------ --- 24.1/26.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  25.7/26.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 7.2 MB/s  0:00:02
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    --------- ------------------------------ 1.6/6.9 MB 10.5 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.9 MB 8.4 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.9 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 8.3 MB/s  0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
# Installing collected packages: watchdog, toml, pyarrow, narwhals, cachetools, blinker, pydeck, altair, streamlit
#
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    -------- ------------------------------- 2/9 [pyarrow]
#    ------------- -------------------------- 3/9 [narwhals]
#    ------------- -------------------------- 3/9 [narwhals]
#    ------------- -------------------------- 3/9 [narwhals]
#    ------------- -------------------------- 3/9 [narwhals]
#    ------------- -------------------------- 3/9 [narwhals]
#    -------------------------- ------------- 6/9 [pydeck]
#    ------------------------------- -------- 7/9 [altair]
#    ------------------------------- -------- 7/9 [altair]
#    ------------------------------- -------- 7/9 [altair]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ----------------------------------- ---- 8/9 [streamlit]
#    ---------------------------------------- 9/9 [streamlit]
#
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.2.2 narwhals-2.11.0 pyarrow-21.0.0 pydeck-0.9.1 streamlit-1.51.0 toml-0.10.2 watchdog-6.0.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (2.1 MB/10.2 MB, attempt 1)
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (9.4 MB/26.2 MB, attempt 1)
#   WARNING: The script watchmedo.exe is installed in 'C:\Users\hp\anaconda3\envs\nlp_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit.exe is installed in 'C:\Users\hp\anaconda3\envs\nlp_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
